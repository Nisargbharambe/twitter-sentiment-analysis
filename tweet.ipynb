# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import nltk
import re
import string

# %%
df=pd.read_csv('tweets_lockdown_1.csv');df.head(100)
# Out:
#     Unnamed: 0                                               text  \
# 0            0  #PopeFrancis expresses his nearness to the peo...
# 1            1  “Post”?We are *in the midst* of the 1st wave o...
# 2            2  #COVID19 | Moderna to start final testing stag...
# 3            3  What a complete moron 🤦‍♂️ #COVIDIOTS #COVIDー1...
# 4            4  I’m actually someone that does believe #corona...
# ..         ...                                                ...
# 95          95  #Malaysia suspends #Hajj pilgrimage for its ci...
# 96          96  Compare and contrast:🇬🇧UK: 7 week delay in loc...
# 97          97  UK tech companies raised $5.3bn from Jan-May 2...
# 98          98  Despite #coronavirus lockdowns slowing daily c...
# 99          99  #BanegaSwasthIndia | Confused about which mask...
#
#                     location  polarity_score  polarity  \
# 0                  in spaces        0.000000   neutral
# 1                        NaN        0.136364  positive
# ...

# %%
temp=df.head(10)['tokens']
temp
# Out:
# 0    ['popefrancis', 'expresses', 'nearness', 'peop...
# 1    ['“post”we', 'midst', '1st', 'wave', 'coronavi...
# 2    ['covid19', 'moderna', 'start', 'final', 'test...
# 3    ['complete', 'moron', '🤦\u200d♂️', 'covidiots'...
# 4    ['i’m', 'actually', 'someone', 'believe', 'cor...
# 5    ['still', 'first', 'wave', 'still', 'first', '...
# 6    ['hightech', 'twist', 'taiwans', 'new', 'life'...
# 7    ['coronavirus', 'covid19', 'indias', 'tally', ...
# 8    ['faucis', 'niaid', 'funded', 'study', 'bat', ...
# 9    ['twometre', 'distance', 'effective', 'one', '...
# Name: tokens, dtype: object

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
wtemp=[word for word in temp if word not in stop_words]
wtemp
# Out:
# ["['popefrancis', 'expresses', 'nearness', 'people', 'brazil', 'telephone', 'call', 'archbishop', 'aparecida', 'coronavi…']",
#  "['“post”we', 'midst', '1st', 'wave', 'coronaviruspandemic', '19', 'states', 'reporting', 'spike', 'new', '…']",
#  "['covid19', 'moderna', 'start', 'final', 'testing', 'stage', 'coronavirus', 'vaccine', 'july', '…']",
#  "['complete', 'moron', '🤦\\u200d♂️', 'covidiots', 'covidー19', 'coronavirus', 'coronacrisis']",
#  "['i’m', 'actually', 'someone', 'believe', 'coronavirus', 'real', 'thing']",
#  "['still', 'first', 'wave', 'still', 'first', 'wave', 'others', 'debate', 'whether', 'accept', '1000', 'deaths…']",
#  "['hightech', 'twist', 'taiwans', 'new', 'life', 'post', 'coronavirus', 'shuttle', 'bus', '5g', 'mobile', 'internet', 'tested', 'betw…']",
#  "['coronavirus', 'covid19', 'indias', 'tally', 'crosses', '285', 'lakh', 'death', 'toll', '8102', '7', 'billion', 'infected', 'worldwide', 'a…']",
# ...

# %%
temp=[]
for x in wtemp:
    for j in x:
        print(j)
# Out:
# [
# '
# p
# o
# p
# e
# f
# r
# a
# n
# c
# i
# s
# '
# ,
#
# '
# e
# x
# p
# r
# e
# s
# s
# e
# s
# '
# ,
#
# '
# n
# e
# a
# r
# n
# e
# s
# s
# '
# ,
#
# '
# p
# e
# o
# p
# l
# e
# '
# ,
#
# '
# b
# r
# a
# z
# i
# l
# '
# ,
#
# '
# t
# e
# l
# e
# p
# h
# o
# n
# e
# '
# ,
#
# '
# c
# a
# l
# l
# '
# ,
#
# '
# a
# r
# c
# h
# b
# i
# s
# h
# o
# p
# '
# ,
#
# '
# a
# p
# a
# r
# e
# c
# i
# d
# a
# '
# ,
#
# '
# c
# o
# r
# o
# n
# a
# v
# i
# …
# '
# ]
# [
# '
# “
# p
# o
# s
# t
# ”
# w
# e
# '
# ,
#
# '
# m
# i
# d
# s
# t
# '
# ,
#
# '
# 1
# s
# t
# '
# ,
#
# '
# w
# a
# v
# e
# '
# ,
#
# '
# c
# o
# r
# o
# n
# a
# v
# i
# r
# u
# s
# p
# a
# n
# d
# e
# m
# i
# c
# '
# ,
#
# '
# 1
# 9
# '
# ,
#
# '
# s
# t
# a
# t
# e
# s
# '
# ,
#
# '
# r
# e
# p
# o
# r
# t
# i
# n
# g
# '
# ,
#
# '
# s
# p
# i
# k
# e
# '
# ,
#
# '
# n
# e
# w
# '
# ,
#
# '
# …
# '
# ]
# [
# '
# c
# o
# v
# i
# d
# 1
# 9
# '
# ,
#
# '
# m
# o
# d
# e
# r
# n
# a
# '
# ,
#
# '
# s
# t
# a
# r
# t
# '
# ...
